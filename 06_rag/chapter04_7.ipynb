# %%
from dotenv import load_dotenv

# API KEY 정보로드
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
model = ChatOpenAI()

prompt = PromptTemplate.from_template("{topic} 에 대하여 3문장으로 설명해줘.")
# 프롬프트와 모델을 연결하여 대화 체인을 생성합니다.
chain = prompt | model | StrOutputParser()

# %%
chain
# Out:
# PromptTemplate(input_variables=['topic'], input_types={}, partial_variables={}, template='{topic} 에 대하여 3문장으로 설명해줘.')
# | ChatOpenAI(metadata={'lc_versions': {'langchain-core': '1.6.3', 'langchain': '1.4.0', 'langchain-openai': '1.6.2'}}, profile={'name': 'GPT-3.5-turbo', 'status': 'deprecated', 'release_date': '2023-03-01', 'last_updated': '2023-11-06', 'open_weights': False, 'max_input_tokens': 16385, 'max_output_tokens': 4096, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': False, 'structured_output': False, 'attachment': False, 'temperature': True, 'image_url_inputs': False, 'pdf_inputs': False, 'pdf_tool_message': False, 'image_tool_message': False, 'tool_choice': True, 'tool_call_streaming': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x000001C9440D41D0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000001C9442E4B00>, root_client=<openai.OpenAI object at 0x000001C9402D53A0>, root_async_client=<openai.AsyncOpenAI object at 0x000001C943F37650>, model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True, stream_chunk_timeout=120.0)
# | StrOutputParser()

# %%
chain.batch([{"topic":"ChatGPT"}, {"topic":"Instagram"}])
# Out:
# ['ChatGPT는 인공지능 채팅 로봇으로, 자연어 처리와 대화 생성을 통해 사용자와 상호작용한다. 사용자의 질문에 대답하거나 대화를 이어가는 등 다양한 대화형태를 지원한다. 딥러닝 알고리즘을 기반으로 하며, 일상적인 대화뿐만 아니라 지식 전달이나 상담 등 다양한 분야에서 활용된다.',
#  'Instagram은 소셜 미디어 플랫폼으로, 사용자들이 사진과 동영상을 공유하고 다른 사람들과 소통할 수 있는 서비스이다. 프로필을 만들고 팔로워를 늘려가며 자신의 콘텐츠를 공유하는 것이 주요 기능이다. 해시태그를 활용하여 다양한 주제의 게시물을 찾고 관심사를 공유하는 등 다양한 활동이 가능하다.']

# %%
answer = chain.batch([{"topic":"ChatGPT"}, {"topic":"Instargram"}])
print(answer)
print(answer[0])
# Out:
# ['ChatGPT 는 인공지능 챗봇으로, 다양한 주제에 대해 대화를 나눌 수 있습니다. 빠르고 정확한 응답을 제공하며 사용자의 질문에 즉각적으로 대응합니다. 그리고 사용자의 피드백을 통해 계속해서 학습하고 발전합니다.', 'Instagram은 사진과 동영상을 공유할 수 있는 소셜 미디어 플랫폼으로, 사용자들은 다양한 콘텐츠를 업로드하고 소통할 수 있습니다. 또한 해시태그를 통해 관심사나 주제별로 다양한 커뮤니티를 형성할 수 있으며, 다양한 필터와 편집 기능을 통해 창의적인 콘텐츠를 제공할 수 있습니다. 또한 인스타그램 스토리를 통해 일상을 간편하게 공유하고 친밀감 있는 소통을 할 수 있습니다.']
# ChatGPT 는 인공지능 챗봇으로, 다양한 주제에 대해 대화를 나눌 수 있습니다. 빠르고 정확한 응답을 제공하며 사용자의 질문에 즉각적으로 대응합니다. 그리고 사용자의 피드백을 통해 계속해서 학습하고 발전합니다.

# %%
# "max_concurrency": 3 동시에 세개씩 처리함.
chain.batch(
    [
        {"topic": "ChatGPT"},
        {"topic": "Instagram"},
        {"topic": "멀티모달"},
        {"topic": "프로그래밍"},
        {"topic": "머신러닝"},
    ],
    config={"max_concurrency": 3},
)
# Out:
# ['ChatGPT는 인공지능 챗봇으로, 다양한 주제에 대해 대화를 나눌 수 있습니다. 사용자의 질문에 응답하거나 일상적인 대화를 나누는데 활용됩니다. 엔터테인먼트, 학습, 또는 정보 서비스로 활용할 수 있습니다.',
#  'Instagram은 사진이나 동영상을 공유하고 친구들과 소통하는 소셜 미디어 플랫폼이다.\n사용자들은 해시태그를 활용하여 관심사에 맞는 콘텐츠를 찾을 수 있고, 팔로워들과 인스타그램 스토리를 통해 일상을 공유할 수 있다.\n인스타그램은 광고 플랫폼으로도 유명하며, 브랜드나 비즈니스들이 제품을 홍보하고 소비자들과 소통하는데 활용된다.',
#  '멀티모달은 여러 가지 다양한 형태의 미디어를 사용하여 정보를 전달하는 방식을 뜻합니다. 이는 텍스트, 이미지, 오디오, 비디오 등 다양한 매체를 조합하여 사용자에게 더 다양하고 풍부한 경험을 제공합니다. 멀티모달은 정보를 전달하는 효율성과 이해도를 높일 뿐만 아니라 사용자의 참여도와 관심을 유발하는 효과를 가져옵니다.',
#  '프로그래밍은 컴퓨터에 명령을 내리는 작업으로, 프로그래머가 원하는 기능과 로직을 코드로 작성하여 실행할 수 있게 합니다. 컴퓨터는 이 코드를 해석해서 사용자가 원하는 작업을 수행하고 결과를 출력합니다. 따라서 프로그래밍은 컴퓨터와 소통하여 원하는 목표를 달성하는 과정입니다.',
#  '머신러닝은 컴퓨터 시스템이 데이터를 분석하고 학습하여 패턴을 발견하고 예측하는 인공지능 기술이다. 이러한 학습과정은 알고리즘을 사용하여 수행되며, 데이터의 양과 품질이 결과에 큰 영향을 미친다. 머신러닝은 예측 분석, 자연어 처리, 이미지 인식 및 결정 지원 등 다양한 분야에서 활용되고 있다.']

# %%
async for token in chain.astream({"topic": "YouTube"}):
    # 메시지 내용을 출력합니다. 줄바꿈 없이 바로 출력하고 버퍼를 비웁니다.
    print(token, end="", flush=True)
# Out:
# YouTube는 구글이 소유하고 운영하는 동영상 공유 플랫폼으로, 사용자들은 영상을 업로드하고 시청할 수 있습니다. 전 세계적으로 매일 수많은 사용자들이 YouTube를 통해 다양한 콘텐츠를 즐기며 소통하고 공유합니다. 수익 창출을 위해 광고 수익과 프리미엄 구독 서비스인 YouTube Premium을 제공하고 있습니다.

# %%
# 비동기 체인 객체의 'ainvoke' 메서드를 호출하여 'NVDA' 토픽을 처리합니다.
my_process = chain.ainvoke({"topic": "NVDA"})

# %%
# 비동기로 처리되는 프로세스가 완료될 때까지 기다립니다.
await my_process
# Out:
# 'NVDA는 NVIDIA Corporation의 주식 종목 심볼로, 세계적인 그래픽 처리 유닛 및 인공지능 기술 회사이다. NVDA 주식은 기술 분야에서 성장하는 기업으로 인정받아 많은 투자자들에게 관심을 받고 있다. NVIDIA의 주력 제품으로는 그래픽 카드, 인공지능을 위한 데스크탑 및 클라우드 기반 솔루션 등이 있다.'
