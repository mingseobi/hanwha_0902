# %%
from dotenv import load_dotenv

# API KEY 정보로드
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
prompt = PromptTemplate.from_template("{topic} 에 대해 쉽게 설명해주세요.")
model = ChatOpenAI()

input = {"topic":"인공지능 모델의 학습 원리"}

# %%
print(prompt)
print(input)
# Out:
# input_variables=['topic'] input_types={} partial_variables={} template='{topic} 에 대해 쉽게 설명해주세요.'
# {'topic': '인공지능 모델의 학습 원리'}

# %%
output_parser = StrOutputParser()
output_parser
# Out:
# StrOutputParser()

# %%
chain = prompt | model | output_parser

# %%
# invoke : 문자열로 된 답변 얻음.
input = {"topic": "인공지능 모델의 학습 원리"}
chain.invoke(input)
# Out:
# '인공지능 모델을 학습시키는 과정은 일반적으로 세 가지 단계로 나눌 수 있습니다.\n\n첫째, 입력 데이터를 모델에 주고 모델이 예측을 수행합니다. 이때 모델은 초기에는 예측이 정확하지 못할 수 있습니다.\n\n둘째, 모델이 만든 예측과 정답 사이의 오차를 계산합니다. 이 오차는 모델의 성능을 나타내는 지표로 사용됩니다.\n\n셋째, 이 오차를 최소화하기 위해 모델을 조정하고 업데이트합니다. 이때 입력 데이터를 다시 사용하여 모델을 계속해서 학습시킵니다.\n\n이러한 과정을 반복하면서 모델은 점차적으로 정확성이 향상되어 가고, 최종적으로는 원하는 작업을 수행할 수 있는 능력을 갖추게 됩니다. 요약하자면, 인공지능 모델은 입력 데이터를 통해 학습하고 예측을 수행하며, 이를 통해 최적화된 결과를 얻는 과정을 반복하는 것입니다.'

# %%
template = """
당신은 영어를 가르치는 10년차 영어 선생님입니다. 주어진 상황에 맞는 영어 회화를 작성해 주세요.
양식은 [FORMAT]을 참고하여 작성해 주세요.

#상황:
{question}

#FORMAT:
- 영어 회화:
- 한글 해석:
"""

# %%
# 프롬프트 템플릿을 이용하여 프롬프트를 생성.
prompt = PromptTemplate.from_template(template)

# ChatOpenAI 챗모델을 초기화.
model = ChatOpenAI(model_name="gpt-4o-mini")

# 문자열 출력 파서를 초기화.
output_parser = StrOutputParser()

# %%
# 체인을 구성합니다.
chain = prompt | model | output_parser

# %%
chain.invoke({"question": "저는 식당에 가서 음식을 주문하고 싶어요"})
# Out:
# "- 영어 회화:\n  - Waiter: Good evening! Welcome to our restaurant. How many people are in your party?\n  - Customer: Good evening! It's just me.\n  - Waiter: Great! Here’s the menu. Can I start you off with something to drink?\n  - Customer: Yes, I’d like a glass of water, please.\n  - Waiter: Sure! Do you need more time to look at the menu or are you ready to order?\n  - Customer: I think I'm ready. I would like the grilled chicken with a side salad.\n  - Waiter: Excellent choice! Would you like any dressing for your salad?\n  - Customer: Yes, please. I’d like balsamic vinaigrette.\n  - Waiter: Perfect! I’ll get that order in for you. Would you like anything else?\n  - Customer: No, that will be all for now. Thank you!\n  - Waiter: You’re welcome! I’ll be right back with your order.\n\n- 한글 해석:\n  - 웨이터: 좋은 저녁입니다! 저희 식당에 오신 것을 환영합니다. 몇 분이서 오셨나요?\n  - 손님: 좋은 저녁입니다! 저 혼자입니다.\n  - 웨이터: 좋습니다! 여기에 메뉴가 있습니다. 음료수 먼저 드릴까요?\n  - 손님: 네, 물 한 잔 주세요.\n  - 웨이터: 알겠습니다! 메뉴를 더 보실 시간이 필요하신가요, 아니면 주문하시겠어요?\n  - 손님: 주문할 준비가 된 것 같아요. 그릴에 구운 치킨과 사이드 샐러드를 주문할게요.\n  - 웨이터: 훌륭한 선택입니다! 샐러드에 드레싱은 어떤 것을 원하시나요?\n  - 손님: 네, 발사믹 비네그레트를 주세요.\n  - 웨이터: 완벽합니다! 주문을 접수하겠습니다. 다른 것도 필요하신가요?\n  - 손님: 아니요, 지금은 그게 전부입니다. 감사합니다!\n  - 웨이터: 천만에요! 주문을 가지고 곧 돌아오겠습니다."

# %%
from langchain_teddynote.messages import stream_response  # 스트리밍 출력
answer = chain.stream({"question": "미국에서 피자 주문"})
# 스트리밍 출력
stream_response(answer)

# 랭스미스 Tracing에서 도 확인해보자 ㅎ
# Out:
# - 영어 회화:
# Customer: Hi there! I'd like to order a pizza, please.
# Pizza Shop: Sure! What size do you want?
# Customer: I'll take a large pepperoni pizza, please.
# Pizza Shop: Would you like any extra toppings?
# Customer: Yes, can you add mushrooms and olives?
# Pizza Shop: Got it! Anything to drink?
# Customer: Just a bottle of water, please.
# Pizza Shop: Great! Your total is $22. Would you like to pay with cash or card?
# Customer: I’ll pay with a card.
# Pizza Shop: Thank you! Your order will be ready in about 30 minutes.
# Customer: Perfect, thank you!
#
# - 한글 해석:
# 고객: 안녕하세요! 피자를 주문하고 싶습니다.
# 피자 가게: 물론이죠! 어떤 사이즈요?
# 고객: 대형 페퍼로니 피자로 주세요.
# 피자 가게: 추가 토핑은 필요하신가요?
# 고객: 네, 버섯과 올리브도 추가해 주세요.
# 피자 가게: 알겠습니다! 음료수는요?
# 고객: 그냥 물 한 병 주세요.
# 피자 가게: 좋습니다! 총 금액은 22달러입니다. 현금으로 결제하시겠어요, 아니면 카드로?
# 고객: 카드를 사용할게요.
# 피자 가게: 감사합니다! 주문하신 피자는 약 30분 안에 준비될 것입니다.
# 고객: 완벽해요, 감사합니다!
